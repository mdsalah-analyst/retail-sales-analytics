# %%
import pandas as pd

df = pd.read_csv("retail_sales_dataset.csv")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
import pandas as pd

df = pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\Bhakti\AppData\Local\Temp\ipykernel_18504\2394721818.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Total Amount'].sum()
# Out:
# np.int64(456000)

# %%
df.groupby('Product Category')['Total Amount'].sum()
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(41.392)

# %%
df.to_csv("clean_retail_sales.csv", index=False)

# %%
df.groupby('Product Category')['Quantity'].sum()
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64

# %%
df.groupby('Gender')['Total Amount'].sum()
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
df.groupby('Age')['Total Amount'].mean()
# Out:
# Age
# 18    534.047619
# 19    708.095238
# 20    411.666667
# 21    629.250000
# 22    507.407407
# 23    342.500000
# 24    361.000000
# 25    495.000000
# 26    635.454545
# 27    408.043478
# 28    412.857143
# 29    410.625000
# 30    445.000000
# 31    464.545455
# 32    292.105263
# 33    624.000000
# 34    599.464286
# 35    513.181818
# 36    607.000000
# 37    728.125000
# 38    584.210526
# 39    255.277778
# 40    392.291667
# 41    269.047619
# 42    326.923077
# 43    579.677419
# 44    504.000000
# 45    372.058824
# 46    523.600000
# 47    480.961538
# 48    402.222222
# 49    268.947368
# 50    428.043478
# 51    535.500000
# 52    320.000000
# 53    559.411765
# 54    375.178571
# 55    465.714286
# 56    496.842105
# 57    309.666667
# 58    528.214286
# 59    557.058824
# 60    526.818182
# 61    373.888889
# 62    300.740741
# 63    544.117647
# 64    294.354839
# Name: Total Amount, dtype: float64

# %%
df.groupby('Date')['Total Amount'].sum()
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
#               ...
# 2023-12-27     700
# 2023-12-28    2075
# 2023-12-29    3400
# 2023-12-31      50
# 2024-01-01    1530
# Name: Total Amount, Length: 345, dtype: int64

# %%
import matplotlib.pyplot as plt

df.groupby('Product Category')['Total Amount'].sum().plot(kind='bar')

plt.title("Sales by Product Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
df.groupby('Gender')['Total Amount'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales Distribution by Gender")
plt.show()

# %%
#SQL Analysis

# %%
df['Total Amount'].sum()
# Out:
# np.int64(456000)

# %%
# category wise sale

# %%
df.groupby('Product Category')['Total Amount'].sum()
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
# Gender wise sales

# %%
df.groupby('Gender')['Total Amount'].sum()
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
#Average age

# %%
df['Age'].mean()
# Out:
# np.float64(41.392)

# %%
# date wise sales

# %%
df.groupby('Date')['Total Amount'].sum()
# Out:
# Date
# 2023-01-01    3600
# 2023-01-02    1765
# 2023-01-03     600
# 2023-01-04    1240
# 2023-01-05    1100
#               ...
# 2023-12-27     700
# 2023-12-28    2075
# 2023-12-29    3400
# 2023-12-31      50
# 2024-01-01    1530
# Name: Total Amount, Length: 345, dtype: int64

# %%
# Week 2 - Advanced Sales Analysis

# %%
#Top 10 Highest Transactions

# %%
df.sort_values(by='Total Amount', ascending=False).head(10)
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 945             946 2023-05-08     CUST946    Male   62      Electronics
# 71               72 2023-05-23     CUST072  Female   20      Electronics
# 14               15 2023-01-16     CUST015  Female   42      Electronics
# 576             577 2023-02-13     CUST577    Male   21           Beauty
# 571             572 2023-04-20     CUST572    Male   31         Clothing
# 268             269 2023-02-01     CUST269    Male   25         Clothing
# 502             503 2023-10-25     CUST503    Male   45           Beauty
# 926             927 2023-06-24     CUST927    Male   43      Electronics
# 252             253 2023-08-31     CUST253  Female   53         Clothing
# 546             547 2023-03-07     CUST547    Male   63         Clothing
#
#      Quantity  Price per Unit  Total Amount
# 945         4             500          2000
# 71          4             500          2000
# ...

# %%
#Average Spending by Gender

# %%
df.groupby('Gender')['Total Amount'].mean()
# Out:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64

# %%
#Quantity Sold by Category

# %%
df.groupby('Product Category')['Quantity'].sum()
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64

# %%
df.groupby('Product Category')['Quantity'].sum().plot(kind='bar')

plt.title("Quantity Sold by Category")
plt.xlabel("Category")
plt.ylabel("Total Quantity")
plt.show()

# %%
#Age Distribution (Customer Analysis)

# %%
df['Age'].plot(kind='hist', bins=10)

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
#Average Spending by Age

# %%
df.groupby('Age')['Total Amount'].mean().plot()

plt.title("Average Spending by Age")
plt.xlabel("Age")
plt.ylabel("Average Spending")
plt.show()

# %%
#Monthly Sales Trend

# %%
df['Month'] = df['Date'].dt.month

df.groupby('Month')['Total Amount'].sum().plot()

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
df.to_csv("clean_retail_sales.csv", index=False)

# %%
df.to_csv("clean_retail_sales.csv", index=False)
